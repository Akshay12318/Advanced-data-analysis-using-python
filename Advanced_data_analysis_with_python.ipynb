# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("superstore.csv",encoding="latin-1")

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df[["Profit","Country"]]
# Out:
#         Profit        Country
# 0      41.9136  United States
# 1     219.5820  United States
# 2       6.8714  United States
# 3    -383.0310  United States
# 4       2.5164  United States
# ...        ...            ...
# 9989    4.1028  United States
# 9990   15.6332  United States
# 9991   19.3932  United States
# 9992   13.3200  United States
# 9993   72.9480  United States
#
# [9994 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail(3)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
# discrete data-unique values countable-useful for continuous data

col_list=["Region","Quantity","Segment","Ship Mode"]
for i in col_list:
    plt.figure(figsize=(10,10))
    sns.countplot(data=df,x=i)
    plt.title(f"{i} countplot")
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
# When two beams/bars are attached then it is histogram, else it is barplot
# histogram is useful when the values is continuous (uncountable - infinity)
col_list=["Profit","Sales","Discount"]
for i in col_list:
    plt.figure(figsize=(10,10))
    plt.hist(data=df,x=i)
    plt.title(f"{i} countplot")
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()

# %%
#distribution plot- it was made on continuous data
col_list=["Profit","Sales","Discount"]
for i in col_list:
    plt.figure(figsize=(10,10))
    sns.displot(data=df,x=i)
    plt.title(f"{i} Distribution plot")
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()

# %%
#distribution plot- it was made on continuous data
col_list=["Profit","Sales","Discount"]
for i in col_list:
    plt.figure(figsize=(10,10))
    sns.boxplot(data=df,x=i)
    plt.title(f"{i} Box plot")
    plt.xlabel(i)
    plt.show()

# %%
np.std(df["Profit"])
# Out:
# 234.24838736035906

# %%
filter_profit=df["Profit"][(df["Profit"]<250) & (df["Profit"]>-250)]

# %%
sns.displot(filter_profit)

# by using std to make a data more readabe as the outliers are more in this case

# %%
filter_profit=df["Sales"][(df["Sales"]<250) & (df["Sales"]>-250)]
sns.displot(filter_profit)

# by using std to make a data more readabe as the outliers are more in this case

# %%
# Here vmin=vertical minimum
# cmap=colouring map
# to find correlation
sns.heatmap(df.corr(numeric_only=True),annot=True,vmin=-1,cmap="coolwarm")
# Out:
# <Axes: >

# %%
df[df["Sales"]==df["Sales"].max()]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  3/18/2014  3/23/2014  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville
#
#         State  Postal Code Region       Product ID    Category Sub-Category  \
# 2697  Florida        32216  South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
#
#       Discount     Profit
# 2697       0.5 -1811.0784

# %%
df[df["Profit"]==df["Profit"].min()]
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 7772    7773  CA-2016-108196  11/25/2016  12/2/2016  Standard Class
#
#      Customer ID  Customer Name   Segment        Country       City State  \
# 7772    CS-12505  Cindy Stewart  Consumer  United States  Lancaster  Ohio
#
#       Postal Code Region       Product ID    Category Sub-Category  \
# 7772        43130   East  TEC-MA-10000418  Technology     Machines
#
#                                    Product Name     Sales  Quantity  Discount  \
# 7772  Cubify CubeX 3D Printer Double Head Print  4499.985         5       0.7
#
#         Profit
# 7772 -6599.978

# %%
df[df["Discount"]==df["Discount"].max()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 14        15  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 15        16  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 75        76  US-2017-118038   12/9/2017  12/11/2017     First Class
# 101      102  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# 169      170  CA-2014-139892    9/8/2014   9/12/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9794    9795  CA-2014-127166   5/21/2014   5/23/2014    Second Class
# 9795    9796  CA-2016-125920   5/21/2016   5/28/2016  Standard Class
# 9808    9809  CA-2017-145093   7/21/2017   7/26/2017  Standard Class
# 9835    9836  CA-2016-126627  10/10/2016  10/12/2016     First Class
# 9920    9921  CA-2016-149272   3/15/2016   3/19/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country         City  \
# ...

# %%
# conclusion:-
# when corelation value tends to 0 or if value in between 0 to 0.5 then it is negative correlation
# If we want to go inside or go know more about the negative correlation ,so at time of decision making we create scatter plot

# sns.scatterplot(data=df,x="Sales",y="Profit")

# %%
sns.scatterplot(data=df,x="Discount",y="Profit")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
# Analysis of scatter plot
# more discount=less profit
# Question:-who gives this discount and how is it calculated?
# till 40% discount acceptable
# It is negatively correlated- it means if given discount is high then profit becomes low.

# %%
# To find probability
round((len(df[df["Discount"]==df["Discount"].max()])/len(df))*100)
# Out:
# 3

# %%
df["Profit"][df["Discount"]==df["Discount"].max()].mean()
# Out:
# np.float64(-101.79679733333333)

# %%
df["Profit"][df["Discount"]==df["Discount"].min()].mean()
# Out:
# np.float64(66.90029245518967)

# %%
# Conclusion:-
# maximum discount of 80% was given to 3% of customers with average loss of 101$
#No discount was given to 48% of customers with average profit of 67$

# %%
df[df["Discount"]==df["Discount"].median()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 7          8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8          9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10        11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11        12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9978    9979  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9979    9980  US-2016-103674   12/6/2016  12/10/2016  Standard Class
# 9981    9982  CA-2017-163566    8/3/2017    8/6/2017     First Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 4       SO-20335    Sean O'Donnell     Consumer  United States
# ...

# %%
round((len(df[df["Discount"]>=df["Discount"].median()])/len(df))*100)
# Out:
# 51

# %%
round((len(df[df["Discount"]<df["Discount"].median()])/len(df))*100)
# Out:
# 49

# %%
# df
# df["Discount"]
# df["Discount"].median()
# df["Profit"][df["Discount"]<df["Discount"].median()]
df["Profit"][df["Discount"]<df["Discount"].median()].mean()
# Out:
# np.float64(67.03797971278317)

# %%
# df["Profit"]
df["Profit"][df["Discount"]>=df["Discount"].median()].mean()
# Out:
# np.float64(-8.918564356435645)

# %%
sns.pairplot(df)

# %%
# create pair plot & if some relation find interesting or informative ,so then create a separate plot of that only which will then help for analysis

# %%
# kde-kernal density estimation plot
col_list=["Profit","Sales","Discount"]
for i in col_list:
    plt.figure(figsize=(10,10))
    sns.kdeplot(data=df,x=i)
    plt.title(f"{i} KDE Plot")
    plt.xlabel(i)

# %%
Col_list=["Region","Quantity","Segment","Ship Mode"]
for i in Col_list:
    plt.figure(figsize=(5,5))
    plt.pie(df[i].value_counts(),labels=df[i].value_counts().index,autopct="%.1f%%")
    plt.title(f"{i} Pie Chart")
    plt.show()

# %%
#violin plot
col_list=["Profit","Sales","Discount"]
for i in col_list:
    plt.figure(figsize=(5,5))
    sns.violinplot(data=df,x=i)
    plt.title(f"{i} Violin Plot")
    plt.xlabel(i)
    plt.show()
